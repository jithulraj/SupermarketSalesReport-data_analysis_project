# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.head(12)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5    263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6     99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8    325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11   846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
#
#      Category  Price  Quantity  Total Payment  Rating
# ...

# %%
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Rating']
# Out:
# 0      2
# 1      3
# 2      5
# 3      1
# 4      4
#       ..
# 995    3
# 996    3
# 997    3
# 998    5
# 999    3
# Name: Rating, Length: 1000, dtype: int64

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales[200 : 211]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
# 210   236950025   3/9/2018  12:40  Female   Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# ...

# %%
sales.tail(10)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 990   Clothing     25         4    100    Cash       5
# 991  Furniture     96         7    672    Card       3
# ...

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Gender']=='Female'].tail(20)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 963   685746853   2/7/2018  20:07  Female    Park lane   Dallas     No
# 965   546718114   1/5/2018  13:41  Female  Water tower  Chicago     No
# 967   838746464  3/12/2018  17:43  Female   Brookfield  NewYork    Yes
# 968   934711328  2/17/2018  17:38  Female  Water tower  Chicago     No
# 971   839513398   3/9/2018  19:08  Female   Brookfield  NewYork    Yes
# 972   322006600   1/8/2018  10:01  Female    Park lane   Dallas     No
# 973    81079897  3/28/2018  12:12  Female    Park lane   Dallas    Yes
# 977   614557665  3/22/2018  17:16  Female    Park lane   Dallas     No
# 979   719253789  3/15/2018  18:37  Female   Brookfield  NewYork     No
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 982   741817151  2/10/2018  14:43  Female   Brookfield  NewYork     No
# 983   169440268  2/17/2018  14:42  Female   Brookfield  NewYork     No
# ...

# %%
sales[sales['Total']<199].head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 7      Books     80         2    160    Cash       3
# 9      Books     80         2    160    Cash       4

# %%
sales[sales['Rating']<3].tail()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 982   741817151  2/10/2018  14:43  Female   Brookfield  NewYork     No
# 985   266635768  1/29/2018  14:30    Male  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 982  Furniture     83         3    249    Gpay       1
# 985  Groceries     39         6    234    Cash       2
# 989   Sporting     19         7    133    Cash       1
# 992      Books     54         1     54    Card       1
# 993   Clothing      3         3      9    Cash       2

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
sales[sales['Payment']=='Cash'].head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 2   Clothing     57         2    114    Cash       5
# 4      Books     82         5    410    Cash       4
# 6   Clothing     81         3    243    Cash       4
# 7      Books     80         2    160    Cash       3

# %%
sales[sales['City']=='NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales[100:200]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 100   515862366  2/12/2018  10:57  Female    Park lane   Dallas     No
# 101    42787009  3/28/2018  11:25  Female    Park lane   Dallas    Yes
# 102   780195692  2/20/2018  12:42  Female    Park lane   Dallas     No
# 103   881639873  2/27/2018  15:05    Male    Park lane   Dallas    Yes
# 104   443388850   2/5/2018  16:31    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 195   343603860   2/4/2018  14:57  Female    Park lane   Dallas     No
# 196   925499362  1/12/2018  11:22  Female   Brookfield  NewYork    Yes
# 197   579316236   3/1/2018  13:44  Female  Water tower  Chicago    Yes
# 198   445531158   2/9/2018  20:19  Female    Park lane   Dallas     No
# 199   805526095  3/27/2018  18:00    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 100   Sporting     94         6    564    Card       3
# ...

# %%
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.sum()['Rating']
# Out:
# 2972

# %%
sales.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales.min()
# Out:
# Invoice ID        661405
# Date            1/1/2018
# Time               10:00
# Gender            Female
# Location      Brookfield
# City             Chicago
# Member                No
# Category           Books
# Price                  1
# Quantity               1
# Total                  1
# Payment             Card
# Rating                 1
# dtype: object

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales[sales['Quantity']==sales.max()['Quantity']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 14    547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 16    397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 30    600792216   3/6/2018  17:04    Male    Park lane   Dallas    Yes
# 35    912473338  2/25/2018  11:27    Male    Park lane   Dallas     No
# 36    209725428  3/20/2018  12:45  Female  Water tower  Chicago    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 983   169440268  2/17/2018  14:42  Female   Brookfield  NewYork     No
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 14     Fashion     98         7    686    Gpay       3
# ...

# %%
sales[sales['Total']==sales.min()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales.mean()['Total']
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_10624\1945902060.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.mean()['Total']
# 207.788

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Price').sum()['Total']
# Out:
# Price
# 1        58
# 2        42
# 3       132
# 4       196
# 5       300
#        ...
# 96     2208
# 97     6402
# 98     3136
# 99     5544
# 100    2300
# Name: Total, Length: 100, dtype: int64

# %%
sales.groupby('Date').mean()['Total']
# Out:
# Date
# 1/1/2018     220.750000
# 1/10/2018    124.000000
# 1/11/2018    195.250000
# 1/12/2018    238.636364
# 1/13/2018    234.000000
#                 ...
# 3/5/2018     271.529412
# 3/6/2018     174.090909
# 3/7/2018     116.444444
# 3/8/2018     239.818182
# 3/9/2018     268.750000
# Name: Total, Length: 89, dtype: float64

# %%
sales.groupby('Price').max()['Total']
# Out:
# Price
# 1        7
# 2       14
# 3       21
# 4       28
# 5       35
#       ...
# 96     672
# 97     679
# 98     686
# 99     693
# 100    500
# Name: Total, Length: 100, dtype: int64

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').min()['Payment']
# Out:
# Gender
# Female    Card
# Male      Card
# Name: Payment, dtype: object

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
sales.groupby('City').max()['Payment']
# Out:
# City
# Chicago    Gpay
# Dallas     Gpay
# NewYork    Gpay
# Name: Payment, dtype: object

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
#which loction have the highest and lowest sale?
#2.Represent the sales on a bar chart and show market share for each location using bar chart

# %%
location_list=sales.groupby('Location')

# %%
location_list

# %%
location=[x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location,sales.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f91fe2c760>,
# ...
#  [Text(0.5080357843151302, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.2771104278082528, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
#which location has more female customers and which location  has more male

# %%
location_sale=sales.groupby(['Gender','Location']).count()['Invoice ID']

# %%
location_sale
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
unstacked_sales=location_sale.unstack(level=0)

# %%
unstacked_sales
# Out:
# Location  Brookfield  Park lane  Water tower
# Gender
# Female           179        179          143
# Male             161        153          185

# %%
unstacked_sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
#what days of a month make more sales?

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sales['Date']).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sales['Date']).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Date, Length: 1000, dtype: int64

# %%
sales.head(6)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4
# 5   Clothing     52         4    208    Gpay       3

# %%
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
sales.head(6)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18
# 5   Clothing     52         4    208    Gpay       3    9

# %%
day_sales=sales.groupby('Day').sum()['Total']

# %%
day_sales
# Out:
# Day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
day_sales.plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
#which branch has more members vs which has less member
#which brach has heighest rating and which has the lowest

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
members=sales.groupby(['Member','Location']).count()['Invoice ID']

# %%
members
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
members_diagram=members.unstack(level=0)

# %%
members_diagram
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
members_diagram.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#second question

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
rating=sales.groupby(['Location']).mean()['Rating']

# %%
rating
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
rating.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#which city has more female shopping?
#who spends more male or female?
#which type of customer spend more member or non member?
#which product line sells more ?
#which product line poppuler among men vs women?

# %%
female_shoppers=sales.groupby(['City','Gender']).count()['Invoice ID']

# %%
female_shoppers
# Out:
# City     Gender
# Chicago  Female    143
#          Male      185
# Dallas   Female    179
#          Male      153
# NewYork  Female    179
#          Male      161
# Name: Invoice ID, dtype: int64

# %%
female_shoppers.unstack(level=0)
# Out:
# City    Chicago  Dallas  NewYork
# Gender
# Female      143     179      179
# Male        185     153      161

# %%
female_shoppers.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
#2

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').sum()['Total'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
#3

# %%
sales.groupby('Member').sum()['Total']
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
sales.groupby('Member').sum()['Total'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Member'>

# %%
#4

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
sales.groupby('Category').count()['Rating']
# Out:
# Category
# Books        165
# Clothing     170
# Fashion      153
# Furniture    160
# Groceries    174
# Sporting     178
# Name: Rating, dtype: int64

# %%
sales.groupby('Category').count()['Rating'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
#5

# %%
sales.groupby(['Category','Gender']).count()['Rating']
# Out:
# Category   Gender
# Books      Female    88
#            Male      77
# Clothing   Female    81
#            Male      89
# Fashion    Female    81
#            Male      72
# Furniture  Female    78
#            Male      82
# Groceries  Female    87
#            Male      87
# Sporting   Female    86
#            Male      92
# Name: Rating, dtype: int64

# %%
sales.groupby(['Category','Gender']).count()['Rating'].unstack(level=0)
# Out:
# Category  Books  Clothing  Fashion  Furniture  Groceries  Sporting
# Gender
# Female       88        81       81         78         87        86
# Male         77        89       72         82         87        92

# %%
sales.groupby(['Category','Gender']).count()['Rating'].unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
#which month make more sales?

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
sales['Month']=pd.to_datetime(sales['Date']).dt.month

# %%
sales['Month']
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Month, Length: 1000, dtype: int64

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  Month
# 0  Groceries     30         1     30    Cash       2   25      1
# 1    Fashion     35         5    175    Card       3   19      3
# 2   Clothing     57         2    114    Cash       5   25      2
# 3   Sporting     89         4    356    Gpay       1   22      1
# 4      Books     82         5    410    Cash       4   18      2

# %%
sales_in_month=sales.groupby('Month').sum()['Total']

# %%
sales_in_month
# Out:
# Month
# 1    71652
# 2    63850
# 3    72286
# Name: Total, dtype: int64

# %%
sales_in_month.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.grid()
